# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/speech.txt").load()

# %%
loader[0].metadata
# Out:
# {'source': '../data/speech.txt'}

# %% [markdown]
# # Pdf loader

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("../data/Jatin_Resume.pdf").load()

# %%
loader[0].page_content
loader[1].page_content
# Out:
# 'Reliability & Infrastructure\n–Co-designed org-level Micronaut (Java) Tier-0 library used across15 services, and Maintained\nzero-downtime database upgrade frameworkreducing maintenance downtime from45 to 60\nminutes to 10 to 15 minutes\nInnovaccerJan 2022 – Sept 2022\nSoftware Engineer Intern to FTENoida, India\n–Developedend-to-end job scheduler servicesupportingCron and ad-hoc executionswith\ndurability guarantees\n–Implemented execution tracking andfault-tolerant retry semanticsfor reliable job processing\n–Builtbackup and restoration systemwithsnapshot-based rollbackto support safe schema and\ndata migrations\nTECHNICAL SKILLS\nLanguages:Java, Golang\nBackend Frameworks:Spring Boot, Micronaut, Dropwizard, Gin\nDatastores:MySQL, Redis, Elasticsearch, DynamoDB\nStreaming & Messaging:Kafka, Kafka Streams (KTable), SQS\nObservability:Datadog, Grafana, Loki, Coralogix\nInfrastructure & Cloud:AWS, Docker, Kubernetes, CI/CD (Jenkins)\nACHIEVEMENTS\n• Delivered20 production-grade Datad
# ...

# %% [markdown]
# # Web page loader

# %%
from langchain_community.document_loaders import WebBaseLoader

# %% [markdown]
# # ArXiv

# %%
from langchain_community.document_loaders import ArxivLoader
docs = ArxivLoader(query="1706.03762", load_max_docs=2).load()
docs

# %% [markdown]
# # WikiPedia

# %%
from langchain_community.document_loaders import WikipediaLoader
loader = WikipediaLoader(query="Python (programming language)", load_max_docs=2).load()
loader[0].page_content
# Out:
# 'Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation. Python is dynamically type-checked and garbage-collected. It supports multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming.\nGuido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language. Python 3.0, released in 2008, was a major revision and not completely backward-compatible with earlier versions. Beginning with Python 3.5, capabilities and keywords for typing were added to the language, allowing optional static typing. As of 2026, the Python Software Foundation supports Python 3.10, 3.11, 3.12, 3.13, and 3.14, following the project\'s annual release cycle and five-year support policy. Python 3.15 is currently in the alpha development phase, and the stable release is expected to come out in October 2026. Earlier versio
# ...
