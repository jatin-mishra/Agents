# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("../data/Jatin_Resume.pdf")

# %%
docs = loader.load()
docs
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-03-27T13:15:01+00:00', 'author': '', 'keywords': '', 'moddate': '2026-03-27T13:15:01+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': '../data/Jatin_Resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Jatin Mishra\nSDE-2 @GoodScore— Ex-CRED, Ex-Innovaccer\n+91-9696658203•jatinm1shra10cr@gmail.com•Linkedin•Github\nWORK EXPERIENCE\nCREDSept 2022 – Dec 2025\nSDE-2 Bangalore, India\nPricing, Deals & Campaign Systems\n–Led team of 3 engineersin end-to-endre-architecture of pricing platformhandling peak of8K\nRPS, mentored2 junior engineerson system design and scalable architectures\n–Designed and implemented fault-tolerant microservices architecture decomposing monolithic system into\nMicronaut(Java) Pricing Store andGolang(Gin) Cataloging Service, Reducing pricing errors by\n50%, leakage in crores, and campaign bandwidth usage by40%\n–Migrated and re-priced90K+ SKUsfrom legacy centralised system withzero downtimeusing\nphased rollout and rollback mechanisms\n–Engineeredconfiguration-driven Golang deal enginesupporting10K concurrent active\ncampaignsat peak withhigh availabilityguarantees, handling25K to 50K SKUs per ingestion\nwith safeguards against price leakage and data corruption\n–ImplementedKafka Streams pipelinesusing1-minute windowed aggregationsprocessing300\nevents per minute, Reducing Elasticsearch node count by44%and infrastructure costs by45%(Rs.\n3L per month savings)\nGrowth, Gifting & User Resurrection\n–Designed and builtfault-tolerant dormant user engagement platforminJava (Spring Boot)\nhandling25K RPS peak trafficwithhigh availability\n–ImplementedS2S and QR-based merchant redemption flowswithidempotent APIsand\nretry-safe workflows, Executed large-scale campaigns reactivating100K dormant users\ncontributing5 to 7%of total reactivations,20% reactivation ratevia non-intent channels\n–Builthigh-throughput gift distribution systempreventing reward leakage under retry-heavy\nconditions with comprehensive monitoring and alerts for tracking reward issuance\nInventory, Catalog & Post-Order Systems\n–Led redesignof inventory synchronisation across8 Java backend serviceshandling300 updates\nper minute, eliminating race conditions using RDBMS transactions withrow-level lockingreducing\nfailures by95%\n– Architected catalog restructuringwith4-level hierarchyin collaboration with product and\nonboarding teams, Redesigned onboarding workflows reducing onboarding time by70%and unlocking\n5% incremental GMV\n–Designedconcurrency-safe return and return-reason workflowsacross distributed services with\nidempotent state transitions, reducing customer escalations by66%\nWealth Management & Payments Platform\n–ArchitectedgenericBFF API and batching frameworkfor app-facing microservice powering40%\nof app screens including landing, reducedp95 latency by 40%(450ms to 270ms) by minimising\nnetwork calls, and with tag based batching\n–Developedreal-time and daily batch computation engineprocessing user transactions to compute\nportfolio KPIs ( returns, allocation drift, and SIP performance metrics etc) at scale'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-03-27T13:15:01+00:00', 'author': '', 'keywords': '', 'moddate': '2026-03-27T13:15:01+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': '../data/Jatin_Resume.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='Reliability & Infrastructure\n–Co-designed org-level Micronaut (Java) Tier-0 library used across15 services, and Maintained\nzero-downtime database upgrade frameworkreducing maintenance downtime from45 to 60\nminutes to 10 to 15 minutes\nInnovaccerJan 2022 – Sept 2022\nSoftware Engineer Intern to FTENoida, India\n–Developedend-to-end job scheduler servicesupportingCron and ad-hoc executionswith\ndurability guarantees\n–Implemented execution tracking andfault-tolerant retry semanticsfor reliable job processing\n–Builtbackup and restoration systemwithsnapshot-based rollbackto support safe schema and\ndata migrations\nTECHNICAL SKILLS\nLanguages:Java, Golang\nBackend Frameworks:Spring Boot, Micronaut, Dropwizard, Gin\nDatastores:MySQL, Redis, Elasticsearch, DynamoDB\nStreaming & Messaging:Kafka, Kafka Streams (KTable), SQS\nObservability:Datadog, Grafana, Loki, Coralogix\nInfrastructure & Cloud:AWS, Docker, Kubernetes, CI/CD (Jenkins)\nACHIEVEMENTS\n• Delivered20 production-grade Datadog dashboards and alerts, applying Apdex-based tuning to\nreduce alert false positives by83%\n• Global Rank 74in CodeChef August Lunchtime (Division 2)\nEDUCATION\nIIIT Sricity 2022\nB.Tech in Computer ScienceAndhra Pradesh\n–CGPA: 7.67 / 10\nJNV, Khairabad (Sitapur)2017\nSenior Secondary (Class XII) — PCMUttar Pradesh\n–Percentage: 94%')]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
# chunk size: how big each chunk should be
# chunk overlap: how much overlap between chunks

# %%
final_documents = text_splitter.split_documents(docs)
final_documents
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-03-27T13:15:01+00:00', 'author': '', 'keywords': '', 'moddate': '2026-03-27T13:15:01+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': '../data/Jatin_Resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Jatin Mishra\nSDE-2 @GoodScore— Ex-CRED, Ex-Innovaccer\n+91-9696658203•jatinm1shra10cr@gmail.com•Linkedin•Github\nWORK EXPERIENCE\nCREDSept 2022 – Dec 2025\nSDE-2 Bangalore, India\nPricing, Deals & Campaign Systems\n–Led team of 3 engineersin end-to-endre-architecture of pricing platformhandling peak of8K\nRPS, mentored2 junior engineerson system design and scalable architectures\n–Designed and implemented fault-tolerant microservices architecture decomposing monolithic system into\nMicronaut(Java) Pricing Store andGolang(Gin) Cataloging Service, Reducing pricing errors by\n50%, leakage in crores, and campaign bandwidth usage by40%\n–Migrated and re-priced90K+ SKUsfrom legacy centralised system withzero downtimeusing\nphased rollout and rollback mechanisms\n–Engineeredconfiguration-driven Golang deal enginesupporting10K concurrent active\ncampaignsat peak withhigh availabilityguarantees, handling25K to 50K SKUs per ingestion\nwith safeguards against price leakage and data corruption'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-03-27T13:15:01+00:00', 'author': '', 'keywords': '', 'moddate': '2026-03-27T13:15:01+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': '../data/Jatin_Resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='–ImplementedKafka Streams pipelinesusing1-minute windowed aggregationsprocessing300\nevents per minute, Reducing Elasticsearch node count by44%and infrastructure costs by45%(Rs.\n3L per month savings)\nGrowth, Gifting & User Resurrection\n–Designed and builtfault-tolerant dormant user engagement platforminJava (Spring Boot)\nhandling25K RPS peak trafficwithhigh availability\n–ImplementedS2S and QR-based merchant redemption flowswithidempotent APIsand\nretry-safe workflows, Executed large-scale campaigns reactivating100K dormant users\ncontributing5 to 7%of total reactivations,20% reactivation ratevia non-intent channels\n–Builthigh-throughput gift distribution systempreventing reward leakage under retry-heavy\nconditions with comprehensive monitoring and alerts for tracking reward issuance\nInventory, Catalog & Post-Order Systems\n–Led redesignof inventory synchronisation across8 Java backend serviceshandling300 updates'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-03-27T13:15:01+00:00', 'author': '', 'keywords': '', 'moddate': '2026-03-27T13:15:01+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': '../data/Jatin_Resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='per minute, eliminating race conditions using RDBMS transactions withrow-level lockingreducing\nfailures by95%\n– Architected catalog restructuringwith4-level hierarchyin collaboration with product and\nonboarding teams, Redesigned onboarding workflows reducing onboarding time by70%and unlocking\n5% incremental GMV\n–Designedconcurrency-safe return and return-reason workflowsacross distributed services with\nidempotent state transitions, reducing customer escalations by66%\nWealth Management & Payments Platform\n–ArchitectedgenericBFF API and batching frameworkfor app-facing microservice powering40%\nof app screens including landing, reducedp95 latency by 40%(450ms to 270ms) by minimising\nnetwork calls, and with tag based batching\n–Developedreal-time and daily batch computation engineprocessing user transactions to compute\nportfolio KPIs ( returns, allocation drift, and SIP performance metrics etc) at scale'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-03-27T13:15:01+00:00', 'author': '', 'keywords': '', 'moddate': '2026-03-27T13:15:01+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': '../data/Jatin_Resume.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='Reliability & Infrastructure\n–Co-designed org-level Micronaut (Java) Tier-0 library used across15 services, and Maintained\nzero-downtime database upgrade frameworkreducing maintenance downtime from45 to 60\nminutes to 10 to 15 minutes\nInnovaccerJan 2022 – Sept 2022\nSoftware Engineer Intern to FTENoida, India\n–Developedend-to-end job scheduler servicesupportingCron and ad-hoc executionswith\ndurability guarantees\n–Implemented execution tracking andfault-tolerant retry semanticsfor reliable job processing\n–Builtbackup and restoration systemwithsnapshot-based rollbackto support safe schema and\ndata migrations\nTECHNICAL SKILLS\nLanguages:Java, Golang\nBackend Frameworks:Spring Boot, Micronaut, Dropwizard, Gin\nDatastores:MySQL, Redis, Elasticsearch, DynamoDB\nStreaming & Messaging:Kafka, Kafka Streams (KTable), SQS\nObservability:Datadog, Grafana, Loki, Coralogix\nInfrastructure & Cloud:AWS, Docker, Kubernetes, CI/CD (Jenkins)\nACHIEVEMENTS'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-03-27T13:15:01+00:00', 'author': '', 'keywords': '', 'moddate': '2026-03-27T13:15:01+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': '../data/Jatin_Resume.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='• Delivered20 production-grade Datadog dashboards and alerts, applying Apdex-based tuning to\nreduce alert false positives by83%\n• Global Rank 74in CodeChef August Lunchtime (Division 2)\nEDUCATION\nIIIT Sricity 2022\nB.Tech in Computer ScienceAndhra Pradesh\n–CGPA: 7.67 / 10\nJNV, Khairabad (Sitapur)2017\nSenior Secondary (Class XII) — PCMUttar Pradesh\n–Percentage: 94%')]

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/speech.txt")

# %%
data = loader.load()
data
# Out:
# [Document(metadata={'source': '../data/speech.txt'}, page_content='This document is designed to simulate real-world input for a Retrieval-Augmented Generation (RAG) pipeline. It contains continuous paragraphs of natural language text instead of structured or line-separated data. The goal is to test how document loaders handle flowing content, paragraph boundaries, and semantic grouping during ingestion. Unlike synthetic datasets with rigid formatting, this format better represents actual content found in blogs, documentation, or knowledge bases.\n\nA typical RAG system begins with document ingestion, where raw text is loaded from various sources such as files, APIs, or databases. The document loader is responsible for reading the content and converting it into a standardized internal representation. This step often involves handling encoding formats, cleaning unwanted characters, and ensuring that the text is preserved accurately. Any inconsistency at this stage can propagate downstream and degrade retrieval quality.\n\nOnce the document is loaded, it is usually split into smaller chunks to facilitate efficient retrieval. Chunking strategies vary depending on the use case, but they typically aim to balance context preservation with retrieval precision. Paragraph-based chunking is often preferred when dealing with long-form content, as it maintains logical coherence. However, overlapping chunks may still be required to avoid losing contextual continuity across boundaries.\n\nAfter chunking, each segment of text is passed through an embedding model, which converts it into a high-dimensional vector representation. These vectors capture the semantic meaning of the text and allow similarity-based retrieval. The quality of embeddings directly impacts the effectiveness of the RAG system, making model selection a critical decision. Lightweight models offer faster processing, while larger models provide better semantic understanding.\n\nThe generated embeddings are stored in a vector database, which enables efficient similarity search operations. When a query is received, it is also converted into a vector and compared against stored embeddings to find the most relevant chunks. This retrieval step is fundamental to RAG, as it determines the context that will be passed to the language model for generation. Poor retrieval leads to irrelevant or incomplete answers.\n\nIn addition to vector search, many systems implement hybrid retrieval techniques that combine semantic search with keyword-based methods such as BM25. This approach improves robustness by capturing both lexical and semantic relevance. Metadata filtering can further refine results by restricting the search space based on attributes like document type, source, or timestamp.\n\nThe retrieved context is then injected into the prompt of a language model, which generates the final response. This augmentation helps ground the model’s output in factual information, reducing hallucination. Prompt design plays a crucial role here, as poorly structured prompts can negate the benefits of retrieval. Ensuring that the context is concise and relevant is key to maintaining response quality.\n\nFrom a systems perspective, performance considerations such as latency, throughput, and scalability must be addressed. Batch processing can improve ingestion efficiency, while parallelization helps handle large datasets. At query time, low latency is essential for a good user experience. Techniques such as caching and approximate nearest neighbor search are often used to optimize response times.\n\nRobustness and fault tolerance are also critical in production environments. Document loaders must handle edge cases such as empty files, corrupted inputs, and unsupported formats gracefully. Logging and monitoring provide visibility into system behavior, enabling faster debugging and issue resolution. Retry mechanisms and fallback strategies help maintain system stability under failure conditions.\n\nSecur ...

# %%
data = ""
with open("../data/speech.txt", "r") as f:
    data = f.read()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=20)
final_documents = text_splitter.create_documents([data])
final_documents
# Out:
# [Document(metadata={}, page_content='This document is designed to simulate real-world input for a Retrieval-Augmented Generation (RAG) pipeline. It contains continuous paragraphs of natural language text instead of structured or line-separated data. The goal is to test how document loaders handle flowing content, paragraph boundaries, and semantic grouping during ingestion. Unlike synthetic datasets with rigid formatting, this format better represents actual content found in blogs, documentation, or knowledge bases.'),
#  Document(metadata={}, page_content='A typical RAG system begins with document ingestion, where raw text is loaded from various sources such as files, APIs, or databases. The document loader is responsible for reading the content and converting it into a standardized internal representation. This step often involves handling encoding formats, cleaning unwanted characters, and ensuring that the text is preserved accurately. Any inconsistency at this stage can propagate downstream and degrade retrieval quality.'),
#  Document(metadata={}, page_content='Once the document is loaded, it is usually split into smaller chunks to facilitate efficient retrieval. Chunking strategies vary depending on the use case, but they typically aim to balance context preservation with retrieval precision. Paragraph-based chunking is often preferred when dealing with long-form content, as it maintains logical coherence. However, overlapping chunks may still be required to avoid losing contextual continuity across boundaries.'),
#  Document(metadata={}, page_content='After chunking, each segment of text is passed through an embedding model, which converts it into a high-dimensional vector representation. These vectors capture the semantic meaning of the text and allow similarity-based retrieval. The quality of embeddings directly impacts the effectiveness of the RAG system, making model selection a critical decision. Lightweight models offer faster processing, while larger models provide better semantic understanding.'),
#  Document(metadata={}, page_content='The generated embeddings are stored in a vector database, which enables efficient similarity search operations. When a query is received, it is also converted into a vector and compared against stored embeddings to find the most relevant chunks. This retrieval step is fundamental to RAG, as it determines the context that will be passed to the language model for generation. Poor retrieval leads to irrelevant or incomplete answers.'),
#  Document(metadata={}, page_content='In addition to vector search, many systems implement hybrid retrieval techniques that combine semantic search with keyword-based methods such as BM25. This approach improves robustness by capturing both lexical and semantic relevance. Metadata filtering can further refine results by restricting the search space based on attributes like document type, source, or timestamp.'),
#  Document(metadata={}, page_content='The retrieved context is then injected into the prompt of a language model, which generates the final response. This augmentation helps ground the model’s output in factual information, reducing hallucination. Prompt design plays a crucial role here, as poorly structured prompts can negate the benefits of retrieval. Ensuring that the context is concise and relevant is key to maintaining response quality.'),
#  Document(metadata={}, page_content='From a systems perspective, performance considerations such as latency, throughput, and scalability must be addressed. Batch processing can improve ingestion efficiency, while parallelization helps handle large datasets. At query time, low latency is essential for a good user experience. Techniques such as caching and approximate nearest neighbor search are often used to optimize response times.'),
#  Document(metadata={}, page_content='Robustness and fault tolerance are also critical in production environments. Document loaders must handle edge cases such as empty files, corrupted inputs, and unsupported formats gracefully. Logging and monitoring provide visibility into system behavior, enabling faster debugging and issue resolution. Retry mechanisms and fallback strategies help maintain system stability under failure conditions.'),
#  Document(metadata={}, page_content='Security and compliance cannot be overlooked, especially when dealing with sensitive data. Personally identifiable information (PII) should be detected and handled appropriately during ingestion. Access control mechanisms must be in place to ensure that only authorized users can query or modify the system. Encryption, both at rest and in transit, is a standard requirement in most deployments.'),
#  Document(metadata={}, page_content='Evaluation of a RAG system involves both quantitative and qualitative measures. Metrics such as precision, recall, and retrieval accuracy provide insight into system performance. However, human evaluation is often necessary to assess the relevance and coherence of generated responses. Continuous iteration based on feedback is essential for improving system quality over time.'),
#  Document(metadata={}, page_content='This document, while simple, serves as a practical test input for validating the behavior of document loaders in a RAG pipeline. It ensures that paragraph-level semantics are preserved and that downstream components receive meaningful input. By using such realistic text samples, developers can identify weaknesses in their ingestion and retrieval strategies and refine their systems accordingly.')]

# %%
type(final_documents[0])
# Out:
# langchain_core.documents.base.Document

# %%
from langchain_text_splitters import CharacterTextSplitter
text_splitter = CharacterTextSplitter(separator="\n", chunk_size=500, chunk_overlap=20)
text_splitter.split_documents(documents=final_documents)
# Out:
# [Document(metadata={}, page_content='This document is designed to simulate real-world input for a Retrieval-Augmented Generation (RAG) pipeline. It contains continuous paragraphs of natural language text instead of structured or line-separated data. The goal is to test how document loaders handle flowing content, paragraph boundaries, and semantic grouping during ingestion. Unlike synthetic datasets with rigid formatting, this format better represents actual content found in blogs, documentation, or knowledge bases.'),
#  Document(metadata={}, page_content='A typical RAG system begins with document ingestion, where raw text is loaded from various sources such as files, APIs, or databases. The document loader is responsible for reading the content and converting it into a standardized internal representation. This step often involves handling encoding formats, cleaning unwanted characters, and ensuring that the text is preserved accurately. Any inconsistency at this stage can propagate downstream and degrade retrieval quality.'),
#  Document(metadata={}, page_content='Once the document is loaded, it is usually split into smaller chunks to facilitate efficient retrieval. Chunking strategies vary depending on the use case, but they typically aim to balance context preservation with retrieval precision. Paragraph-based chunking is often preferred when dealing with long-form content, as it maintains logical coherence. However, overlapping chunks may still be required to avoid losing contextual continuity across boundaries.'),
#  Document(metadata={}, page_content='After chunking, each segment of text is passed through an embedding model, which converts it into a high-dimensional vector representation. These vectors capture the semantic meaning of the text and allow similarity-based retrieval. The quality of embeddings directly impacts the effectiveness of the RAG system, making model selection a critical decision. Lightweight models offer faster processing, while larger models provide better semantic understanding.'),
#  Document(metadata={}, page_content='The generated embeddings are stored in a vector database, which enables efficient similarity search operations. When a query is received, it is also converted into a vector and compared against stored embeddings to find the most relevant chunks. This retrieval step is fundamental to RAG, as it determines the context that will be passed to the language model for generation. Poor retrieval leads to irrelevant or incomplete answers.'),
#  Document(metadata={}, page_content='In addition to vector search, many systems implement hybrid retrieval techniques that combine semantic search with keyword-based methods such as BM25. This approach improves robustness by capturing both lexical and semantic relevance. Metadata filtering can further refine results by restricting the search space based on attributes like document type, source, or timestamp.'),
#  Document(metadata={}, page_content='The retrieved context is then injected into the prompt of a language model, which generates the final response. This augmentation helps ground the model’s output in factual information, reducing hallucination. Prompt design plays a crucial role here, as poorly structured prompts can negate the benefits of retrieval. Ensuring that the context is concise and relevant is key to maintaining response quality.'),
#  Document(metadata={}, page_content='From a systems perspective, performance considerations such as latency, throughput, and scalability must be addressed. Batch processing can improve ingestion efficiency, while parallelization helps handle large datasets. At query time, low latency is essential for a good user experience. Techniques such as caching and approximate nearest neighbor search are often used to optimize response times.'),
#  Document(metadata={}, page_content='Robustness and fault tolerance are also critical in production environments. Document loaders must handle edge cases such as empty files, corrupted inputs, and unsupported formats gracefully. Logging and monitoring provide visibility into system behavior, enabling faster debugging and issue resolution. Retry mechanisms and fallback strategies help maintain system stability under failure conditions.'),
#  Document(metadata={}, page_content='Security and compliance cannot be overlooked, especially when dealing with sensitive data. Personally identifiable information (PII) should be detected and handled appropriately during ingestion. Access control mechanisms must be in place to ensure that only authorized users can query or modify the system. Encryption, both at rest and in transit, is a standard requirement in most deployments.'),
#  Document(metadata={}, page_content='Evaluation of a RAG system involves both quantitative and qualitative measures. Metrics such as precision, recall, and retrieval accuracy provide insight into system performance. However, human evaluation is often necessary to assess the relevance and coherence of generated responses. Continuous iteration based on feedback is essential for improving system quality over time.'),
#  Document(metadata={}, page_content='This document, while simple, serves as a practical test input for validating the behavior of document loaders in a RAG pipeline. It ensures that paragraph-level semantics are preserved and that downstream components receive meaningful input. By using such realistic text samples, developers can identify weaknesses in their ingestion and retrieval strategies and refine their systems accordingly.')]

# %% [markdown]
# # HTML Text Splitter

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

# %%
html_string = """
<!Doctype html>
<html>
    <head>
        <title>My HTML Document</title>
    </head>
    <body>
        <h1>Heading 1</h1>
        <p>This is a paragraph under heading 1.</p>
        <h2>Heading 2</h2>
        <p>This is a paragraph under heading 2.</p>
        <h3>Heading 3</h3>
        <p>This is a paragraph under heading 3.</p>
    </body>
</html>
"""

# %%
headers_to_split_on = [
    ("h1", "Heading 1"),
    ("h2", "Heading 2"),
    ("h3", "Heading 3")
]
header_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
html_header_splits = header_splitter.split_text(html_string)
html_header_splits
# Out:
# [Document(metadata={'Heading 1': 'Heading 1'}, page_content='Heading 1'),
#  Document(metadata={'Heading 1': 'Heading 1'}, page_content='This is a paragraph under heading 1.'),
#  Document(metadata={'Heading 1': 'Heading 1', 'Heading 2': 'Heading 2'}, page_content='Heading 2'),
#  Document(metadata={'Heading 1': 'Heading 1', 'Heading 2': 'Heading 2'}, page_content='This is a paragraph under heading 2.'),
#  Document(metadata={'Heading 1': 'Heading 1', 'Heading 2': 'Heading 2', 'Heading 3': 'Heading 3'}, page_content='Heading 3'),
#  Document(metadata={'Heading 1': 'Heading 1', 'Heading 2': 'Heading 2', 'Heading 3': 'Heading 3'}, page_content='This is a paragraph under heading 3.')]

# %% [markdown]
# # Json splitter

# %%
import json 
import requests

# %%
json_data = requests.get("https://api.smith.langchain.com/openapi.json").json()

# %%
# json_data

# %%
from langchain_text_splitters import RecursiveJsonSplitter
json_splitter = RecursiveJsonSplitter(max_chunk_size=1000)
json_chunks = json_splitter.split_json(json_data)
json_chunks
# Out:
# [{'openapi': '3.1.0',
#   'info': {'title': 'LangSmith',
#    'description': 'The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n',
#    'version': '0.1.0'},
#   'paths': {'/api/v1/audit-logs': {'get': {'tags': ['audit-logs'],
#      'summary': 'Get Audit Logs',
#      'description': "Retrieve audit log records for the authenticated user's organization in OCSF format.\n\nRequires both start_time and end_time parameters to filter logs within a date range.\nSupports cursor-based pagination.\n\nReturns results in OCSF API Activity (Class UID: 6003) format,\nwhich is compatible with security monitoring and SIEM tools.\nReference: https://schema.ocsf.io/1.7.0/classes/api_activity",
#      'operationId': 'get_audit_logs_api_v1_audit_logs_get'}}}},
#  {'paths': {'/api/v1/audit-logs': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}],
#      'parameters': [{'name': 'limit',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'integer',
#         'maximum': 100,
#         'minimum': 1,
#         'description': 'Number of items to return',
#         'default': 10,
#         'title': 'Limit'},
#        'description': 'Number of items to return'},
#       {'name': 'cursor',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'description': 'Cursor for pagination (base64-encoded JSON string)',
#         'title': 'Cursor'},
#        'description': 'Cursor for pagination (base64-encoded JSON string)'},
#       {'name': 'workspace_id',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string', 'format': 'uuid'},
#          {'type': 'null'}],
#         'description': 'Filter by workspace ID',
#         'title': 'Workspace Id'},
#        'description': 'Filter by workspace ID'},
#       {'name': 'start_time',
#        'in': 'query',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'date-time',
#         'description': 'Start datetime (inclusive) in ISO 8601 format',
#         'title': 'Start Time'},
#        'description': 'Start datetime (inclusive) in ISO 8601 format'},
#       {'name': 'end_time',
#        'in': 'query',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'date-time',
#         'description': 'End datetime (inclusive) in ISO 8601 format',
#         'title': 'End Time'},
#        'description': 'End datetime (inclusive) in ISO 8601 format'},
#       {'name': 'operations',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'array',
#           'items': {'$ref': '#/components/schemas/AuditLogOperation'}},
#          {'type': 'null'}],
#         'description': 'Filter by operation names. If omitted, all operations are returned.',
#         'title': 'Operations'},
#        'description': 'Filter by operation names. If omitted, all operations are returned.'}]}}}},
#  {'paths': {'/api/v1/audit-logs': {'get': {'responses': {'200': {'description': 'Successful Response',
#        'content': {'application/json': {'schema': {'$ref': '#/components/schemas/ListAuditLogsOCSFResponse'}}}},
#       '422': {'description': 'Validation Error',
#        'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}},
#    '/api/v1/sessions/{session_id}/dashboard': {'post': {'tags': ['tracer-sessions'],
#      'summary': 'Get Tracing Project Prebuilt Dashboard',
#      'description': 'Get a prebuilt dashboard for a tracing project.',
#      'operationId': 'get_tracing_project_prebuilt_dashboard_api_v1_sessions__session_id__dashboard_post',
#      'security': [{'API Key': []}, {'Tenant ID': []}, {'Bearer Auth': []}],
#      'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'accept',
#        'in': 'header',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Accept'}}]}}}}]

# %%
i = 0
for chunk in json_chunks:
    print(chunk)
    print("\n\n")
    if i == 2:
        break
    i+=1
# Out:
# {'openapi': '3.1.0', 'info': {'title': 'LangSmith', 'description': 'The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n', 'version': '0.1.0'}, 'paths': {'/api/v1/audit-logs': {'get': {'tags': ['audit-logs'], 'summary': 'Get Audit Logs', 'description': "Retrieve audit log records for the authenticated user's organization in OCSF format.\n\nRequires both start_time and end_time parameters to filter logs within a date range.\nSupports cursor-based pagination.\n\nReturns results in OCSF API Activity (Class UID: 6003) format,\nwhich is compatible with security monitoring and SIEM tools.\nReference: https://schema.ocsf.io/1.7.0/classes/api_activity", 'operationId': 'get_audit_logs_api_v1_audit_logs_get'}}}}
#
#
#
# {'paths': {'/api/v1/audit-logs': {'get': {'security': [{'API Key': []}, {'Organization ID': []}, {'Bearer Auth': []}], 'parameters': [{'name': 'limit', 'in': 'query', 'required': False, 'schema': {'type': 'integer', 'maximum': 100, 'minimum': 1, 'description': 'Number of items to return', 'default': 10, 'title': 'Limit'}, 'description': 'Number of items to return'}, {'name': 'cursor', 'in': 'query', 'required': False, 'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'description': 'Cursor for pagination (base64-encoded JSON string)', 'title': 'Cursor'}, 'description': 'Cursor for pagination (base64-encoded JSON string)'}, {'name': 'workspace_id', 'in': 'query', 'required': False, 'schema': {'anyOf': [{'type': 'string', 'format': 'uuid'}, {'type': 'null'}], 'description': 'Filter by workspace ID', 'title': 'Workspace Id'}, 'description': 'Filter by workspace ID'}, {'name': 'start_time', 'in': 'query', 'required': True, 'schema': {'type': 'string', 'format': 'date-time', 'description': 'Start datetime (inclusive) in ISO 8601 format', 'title': 'Start Time'}, 'description': 'Start datetime (inclusive) in ISO 8601 format'}, {'name': 'end_time', 'in': 'query', 'required': True, 'schema': {'type': 'string', 'format': 'date-time', 'description': 'End datetime (inclusive) in ISO 8601 format', 'title': 'End Time'}, 'description': 'End datetime (inclusive) in ISO 8601 format'}, {'name': 'operations', 'in': 'query', 'required': False, 'schema': {'anyOf': [{'type': 'array', 'items': {'$ref': '#/components/schemas/AuditLogOperation'}}, {'type': 'null'}], 'description': 'Filter by operation names. If omitted, all operations are returned.', 'title': 'Operations'}, 'description': 'Filter by operation names. If omitted, all operations are returned.'}]}}}}
#
#
#
# {'paths': {'/api/v1/audit-logs': {'get': {'responses': {'200': {'description': 'Successful Response', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/ListAuditLogsOCSFResponse'}}}}, '422': {'description': 'Validation Error', 'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}, '/api/v1/sessions/{session_id}/dashboard': {'post': {'tags': ['tracer-sessions'], 'summary': 'Get Tracing Project Prebuilt Dashboard', 'description': 'Get a prebuilt dashboard for a tracing project.', 'operationId': 'get_tracing_project_prebuilt_dashboard_api_v1_sessions__session_id__dashboard_post', 'security': [{'API Key': []}, {'Tenant ID': []}, {'Bearer Auth': []}], 'parameters': [{'name': 'session_id', 'in': 'path', 'required': True, 'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}}, {'name': 'accept', 'in': 'header', 'required': False, 'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Accept'}}]}}}}

# %%
docs = json_splitter.create_documents(json_chunks)
for doc in docs[:3]:
    print(doc)
    print("\n\n")
# Out:
# page_content='{"openapi": "3.1.0", "info": {"title": "LangSmith", "description": "The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n", "version": "0.1.0"}, "paths": {"/api/v1/audit-logs": {"get": {"tags": ["audit-logs"], "summary": "Get Audit Logs", "description": "Retrieve audit log records for the authenticated user's organization in OCSF format.\n\nRequires both start_time and end_time parameters to filter logs within a date range.\nSupports cursor-based pagination.\n\nReturns results in OCSF API Activity (Class UID: 6003) format,\nwhich is compatible with security monitoring and SIEM tools.\nReference: https://schema.ocsf.io/1.7.0/classes/api_activity", "operationId": "get_audit_logs_api_v1_audit_logs_get"}}}}'
#
#
#
# page_content='{"paths": {"/api/v1/audit-logs": {"get": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}], "parameters": [{"name": "limit", "in": "query", "required": false, "schema": {"type": "integer", "maximum": 100, "minimum": 1, "description": "Number of items to return", "default": 10, "title": "Limit"}, "description": "Number of items to return"}, {"name": "cursor", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "description": "Cursor for pagination (base64-encoded JSON string)", "title": "Cursor"}, "description": "Cursor for pagination (base64-encoded JSON string)"}, {"name": "workspace_id", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string", "format": "uuid"}, {"type": "null"}], "description": "Filter by workspace ID", "title": "Workspace Id"}, "description": "Filter by workspace ID"}, {"name": "start_time", "in": "query", "required": true, "schema": {"type": "string", "format": "date-time", "description": "Start datetime (inclusive) in ISO 8601 format", "title": "Start Time"}, "description": "Start datetime (inclusive) in ISO 8601 format"}, {"name": "end_time", "in": "query", "required": true, "schema": {"type": "string", "format": "date-time", "description": "End datetime (inclusive) in ISO 8601 format", "title": "End Time"}, "description": "End datetime (inclusive) in ISO 8601 format"}, {"name": "operations", "in": "query", "required": false, "schema": {"anyOf": [{"type": "array", "items": {"$ref": "#/components/schemas/AuditLogOperation"}}, {"type": "null"}], "description": "Filter by operation names. If omitted, all operations are returned.", "title": "Operations"}, "description": "Filter by operation names. If omitted, all operations are returned."}]}}}}'
#
#
#
# page_content='{"paths": {"/api/v1/audit-logs": {"get": {"responses": {"200": {"description": "Successful Response", "content": {"application/json": {"schema": {"$ref": "#/components/schemas/ListAuditLogsOCSFResponse"}}}}, "422": {"description": "Validation Error", "content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}, "/api/v1/sessions/{session_id}/dashboard": {"post": {"tags": ["tracer-sessions"], "summary": "Get Tracing Project Prebuilt Dashboard", "description": "Get a prebuilt dashboard for a tracing project.", "operationId": "get_tracing_project_prebuilt_dashboard_api_v1_sessions__session_id__dashboard_post", "security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}], "parameters": [{"name": "session_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Session Id"}}, {"name": "accept", "in": "header", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "title": "Accept"}}]}}}}'
